# %% [markdown]
# # Generate Geometry

# %% [markdown]
# ## Weird Geometry Generation using nanomesh

# %%
from skimage.morphology import disk
from nanomesh.data import binary_blobs2d

# Data must be normalized before using it in FEM
data = binary_blobs2d(length=100, volume_fraction=0.4)

from nanomesh import Mesher

mesher = Mesher(data)
mesher.generate_contour(max_edge_dist=10, precision=1)
mesh = mesher.triangulate(opts='q30a25')

triangles = mesh.get('triangle')
triangles.remove_cells(label=2, key='physical')

triangles.plot()
# Out:
# <Axes: title={'center': 'triangle mesh'}>

# %%
print(triangles)
# Out:
# TriangleMesh(
#     points = (256, 2),
#     cells = (385, 3),
#     fields = ('X', 'background'),
#     region_markers = (),
#     cell_data = ('physical',),
# )

# %%
print(triangles.points)
# Out:
# [[ 0.         63.5       ]
#  [ 9.         59.5       ]
#  [13.5        55.        ]
#  [17.5        47.        ]
#  [17.5        37.        ]
#  [15.5        33.        ]
#  [ 9.         26.5       ]
#  [ 0.         22.5       ]
#  [47.5        40.        ]
#  [47.5        33.        ]
#  [44.5        27.        ]
#  [41.5        13.        ]
#  [36.          7.5       ]
#  [33.          6.5       ]
#  [24.          7.5       ]
#  [18.5        13.        ]
#  [17.5        16.        ]
#  [17.5        23.        ]
#  [20.5        30.        ]
#  [22.5        42.        ]
#  [29.         48.5       ]
#  [38.         49.5       ]
#  [41.         48.5       ]
#  [46.5        43.        ]
#  [42.5        81.        ]
#  [42.5        75.        ]
#  [40.5        71.        ]
#  [33.         65.5       ]
#  [24.         66.5       ]
#  [18.5        72.        ]
#  [17.5        75.        ]
#  [17.5        81.        ]
#  [19.5        85.        ]
#  [27.         90.5       ]
#  [33.         90.5       ]
#  [37.         88.5       ]
#  [85.5        99.        ]
#  [88.5        92.        ]
#  [87.5        82.        ]
#  [94.5        72.        ]
#  [95.5        63.        ]
#  [92.5        57.        ]
#  [86.5        51.        ]
#  [83.5        41.        ]
#  [76.         35.5       ]
#  [69.         35.5       ]
#  [65.         37.5       ]
#  [59.5        45.        ]
#  [60.5        54.        ]
#  [69.5        66.        ]
#  [68.5        73.        ]
#  [60.5        80.        ]
#  [57.5        87.        ]
#  [57.5        92.        ]
#  [60.5        99.        ]
#  [99.         16.5       ]
#  [91.         18.5       ]
#  [85.5        26.        ]
#  [86.5        36.        ]
#  [94.         41.5       ]
#  [99.         41.5       ]
#  [ 0.          0.        ]
#  [99.          0.        ]
#  [99.         99.        ]
#  [ 0.         99.        ]
#  [49.5         0.        ]
#  [99.         70.25      ]
#  [30.25       99.        ]
#  [24.75        0.        ]
#  [99.         55.875     ]
#  [37.125       0.        ]
#  [99.         63.0625    ]
#  [12.6818276  12.72727587]
#  [30.9375      0.        ]
#  [ 0.         81.25      ]
#  [41.27272413 54.3181724 ]
#  [52.3181724  43.27272413]
#  [95.         67.5       ]
#  [231 233 232]
#  [ 62 252 254]
#  [233 255 254]]

# %%
help(triangles)
# Out:
# Help on TriangleMesh in module nanomesh.mesh._triangle object:
#
# class TriangleMesh(nanomesh.mesh._mesh.Mesh, nanomesh.mesh._mixin.PruneZ0Mixin)
#  |  TriangleMesh(points: 'np.ndarray', cells: 'np.ndarray', *args, **kwargs)
#  |
#  |  Data class for triangle meshes.
#  |
#  |  Depending on the number of dimensions of the cells, the appropriate
#  |  subclass will be chosen if possible.
#  |
#  |  Parameters
#  |  ----------
#  |  points : (m, 2 or 3) numpy.ndarray[float]
#  |      Array with points.
#  |  cells : (i, 3) numpy.ndarray[int]
#  |      Index array describing the cells of the mesh.
#  |  fields : Dict[str, int]:
#  |      Mapping from field names to labels
#  |  region_markers : RegionMarkerList, optional
#  |      List of region markers used for assigning labels to regions.
#  |      Defaults to an empty list.
#  |  **cell_data
#  |      Additional cell data. Argument must be a 1D numpy array
#  |      matching the number of cells defined by `i`.
#  |
#  |  Method resolution order:
#  |      TriangleMesh
#  |      nanomesh.mesh._mesh.Mesh
#  |      nanomesh.mesh._mixin.PruneZ0Mixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  crop(self, xmin: 'float' = -inf, xmax: 'float' = inf, ymin: 'float' = -inf, ymax: 'float' = inf, zmin: 'float' = -inf, zmax: 'float' = inf, include_partial: 'bool' = False) from nanomesh.mesh._mesh.Mesh
#  |      Crop mesh to given region.
#  |
#  |      Parameters
#  |      ----------
#  |      xmin : float, optional
#  |          Minimum x value.
#  |      xmax : float, optional
#  |          Maximum x value.
#  |      ymin : float, optional
#  |          Minimum y value.
#  |      ymax : float, optional
#  |          Maximum y value.
#  |      zmin : float, optional
#  |          Minimum z value (3D point data only).
#  |      zmax : float, optional
#  |          Maximum z value (3D point data only).
#  |      include_partial : bool, optional
#  |          If True, include cells that are partially inside the
#  |          given crop region, i.e. one of its points is inside.
#  |
#  |      Returns
#  |      -------
#  |      cropped_mesh : :class:`TriangleMesh`
#  |          Cropped mesh
#  |
#  |  optimize(self, *, method='CVT (block-diagonal)', tol: 'float' = 0.001, max_num_steps: 'int' = 10, **kwargs) -> 'TriangleMesh'
#  |      Optimize mesh using :mod:`optimesh`.
#  |
#  |      Parameters
#  |      ----------
#  |      method : str, optional
#  |          Method name
#  |      tol : float, optional
#  |          Tolerance
#  |      max_num_steps : int, optional
#  |          Maximum number of optimization steps.
#  |      **kwargs
#  |          Arguments to pass to :func:`optimesh.optimize_points_cells`
#  |
#  |      Returns
#  |      -------
#  |      TriangleMesh
#  |
#  |  plot(self, **kwargs)
#  |      Shortcut for :meth:`TriangleMesh.plot_mpl` or
#  |      :meth:`TriangleMesh.plot_itk` depending on dimensions.
#  |
#  |  plot_mpl(self, *args, **kwargs) -> 'plt.Axes'
#  |      Simple triangle mesh plot using :mod::mod:`matplotlib`. See
#  |      :func:`plotting.trianglemeshplot` for details.
#  |
#  |      Parameters
#  |      ----------
#  |      *args
#  |          Arguments passed to :func:`plotting.trianglemeshplot`
#  |      **kwargs
#  |          Keyword arguments passed to :func:`plotting.trianglemeshplot`
#  |
#  |      Returns
#  |      -------
#  |      plt.Axes
#  |
#  |  reverse_cell_order(self) from nanomesh.mesh._mesh.Mesh
#  |      Reverse order of cells and cell data.
#  |
#  |      Updates :attr:`TriangleMesh.cell_data`.
#  |
#  |  tetrahedralize(self, **kwargs) -> "'MeshContainer'"
#  |      Tetrahedralize mesh using :func:`tetrahedralize`.
#  |
#  |      Parameters
#  |      ----------
#  |      mesh : TriangleMesh
#  |          Input contour mesh
#  |      opts : str, optional
#  |          Command-line options passed to `tetgen`.
#  |
#  |          More info:
#  |          http://wias-berlin.de/software/tetgen/1.5/doc/manual/manual005.html
#  |
#  |          Some useful flags:
#  |
#  |          - `-A`: Assigns attributes to tetrahedra in different regions.
#  |          - `-p`: Tetrahedralizes a piecewise linear complex (PLC).
#  |          - `-q`: Refines mesh (to improve mesh quality).
#  |          - `-a`: Applies a maximum tetrahedron volume constraint.
#  |
#  |          Can be passed as a raw string, `opts='-pAq1.2', or dict,
#  |          `opts=dict('p'= True, 'A'= True, 'q'=1.2)`.
#  |      default_opts : dict, optional
#  |          Dictionary with default options. These will be merged with `opts`.
#  |
#  |      Returns
#  |      -------
#  |      MeshContainer
#  |          Tetrahedralized mesh.
#  |
#  |  to_open3d(self) -> "'open3d.geometry.TriangleMesh'"
#  |      Return instance of :class:`open3d.geometry.TriangleMesh`.
#  |
#  |  to_polydata(self) -> "'pv.PolyData'"
#  |      Return instance of :class:`pyvista.Polydata`.
#  |
#  |  to_trimesh(self)
#  |      Return instance of :class:`trimesh.Trimesh`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_open3d(mesh: "'open3d.geometry.TriangleMesh'") -> 'TriangleMesh'
#  |      Return instance of :class:`TriangleMesh` from open3d.
#  |
#  |  from_scipy(mesh: "'scipy.spatial.qhull.Delaunay'") -> 'TriangleMesh'
#  |      Return instance of :class:`TriangleMesh` from
#  |      :class:`scipy.spatial.Delaunay` object.
#  |
#  |  from_triangle_dict(dct: 'dict') -> 'TriangleMesh'
#  |      Return instance of :class:`TriangleMesh` from triangle results
#  |      dict.
#  |
#  |  from_trimesh(mesh) -> 'TriangleMesh'
#  |      Return instance of :class:`TriangleMesh` from :mod:`trimesh`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  from_meshio() from nanomesh.mesh._mesh.Mesh
#  |      Return :class:`TriangleMesh` from meshio object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  number_to_field
#  |      Mapping from numbers to fields, proxy to
#  |      :attr:`TriangleMesh.field_to_number`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  cell_type = 'triangle'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nanomesh.mesh._mesh.Mesh:
#  |
#  |  __init__(self, points: 'np.ndarray', cells: 'np.ndarray', *, fields: 'Dict[str, int]' = None, region_markers: 'RegionMarkerList' = None, **cell_data)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self, indent: 'int' = 0)
#  |      Canonical string representation.
#  |
#  |  get_cell_data(self, key: 'str', default_value: 'float' = 0) -> 'np.ndarray'
#  |      Get cell data with optional default value.
#  |
#  |      Parameters
#  |      ----------
#  |      key : str
#  |          Key of the cell data to retrieve.
#  |      default_value : float, optional
#  |          Optional default value (if cell data does not exist)
#  |
#  |      Returns
#  |      -------
#  |      numpy.ndarray
#  |
#  |  plot_itk(self, **kwargs)
#  |      Wrapper for :func:`pyvista.plot_itk`.
#  |
#  |      Parameters
#  |      ----------
#  |      **kwargs
#  |          These parameters are passed to :func:`pyvista.plot_itk`
#  |
#  |  plot_pyvista(self, **kwargs)
#  |      Wrapper for :func:`pyvista.plot`.
#  |
#  |      Parameters
#  |      ----------
#  |      **kwargs
#  |          These parameters are passed to :func:`pyvista.plot`
#  |
#  |  remove_cells(self, *, label: 'int', key: 'str' = None)
#  |      Remove cells with cell data matching given label.
#  |
#  |      Parameters
#  |      ----------
#  |      label : int
#  |          All cells with this label will be removed.
#  |      key : str, optional
#  |          The key of the cell data to use.
#  |          Uses :attr:`Mesh.default_key` if None.
#  |
#  |  remove_loose_points(self)
#  |      Remove points that do not belong to any cells.
#  |
#  |  to_meshio(self) -> "'meshio.Mesh'"
#  |      Return instance of :func:`meshio.Mesh`.
#  |
#  |  to_pyvista_unstructured_grid(self) -> "'pv.PolyData'"
#  |      Return instance of :class:`pyvista.UnstructuredGrid`.
#  |
#  |      References
#  |      ----------
#  |      https://docs.pyvista.org/core/point-grids.html#pv-unstructured-grid-class-methods
#  |
#  |  write(self, *args, **kwargs)
#  |      Simple wrapper around :func:`meshio.write`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from nanomesh.mesh._mesh.Mesh:
#  |
#  |  __init_subclass__(cell_dim: 'int', **kwargs)
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.
#  |
#  |  read(filename, **kwargs)
#  |      Simple wrapper around :func:`meshio.read`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from nanomesh.mesh._mesh.Mesh:
#  |
#  |  __new__(cls, points: 'np.ndarray', cells: 'np.ndarray', *args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from nanomesh.mesh._mesh.Mesh:
#  |
#  |  cell_centers
#  |      Return centers of cells (mean of corner points).
#  |
#  |  dimensions
#  |      Return number of dimensions for point data.
#  |
#  |  zero_labels
#  |      Return zero labels as fallback.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nanomesh.mesh._mesh.Mesh:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  labels
#  |      Shortcut for cell labels.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nanomesh.mesh._mixin.PruneZ0Mixin:
#  |
#  |  prune_z_0(self)
#  |      Drop third dimension (z) coordinates if present and all values are
#  |      equal to 0 (within tolerance).
#  |
#  |      For compatibility, sometimes a column with zeroes is added, for
#  |      example when exporting to gmsh2.2 format. This method drops that
#  |      column.

# %% [markdown]
# ## Translate to FEMSolver
